# %% [markdown]
# # Proyecto Final: Análisis de Big Data con Spark y HDFS
# ## Visión general:
# Este proyecto está diseñado para ayudarte a adquirir experiencia práctica con Spark y HD
# Trabajarás con tu propio conjunto de datos y utilizarás Spark para analizar los datos, obte
# información y generar resultados en diferentes formatos de salida y fuentes. También util
# Spark Structured Streaming para realizar análisis en tiempo real de los datos utilizando
# ## Entorno:
# Ejecutarás este proyecto en tu propia computadora personal utilizando un entorno con
# contenedores Docker que contienen Spark 3 y HDFS Py

# %% [markdown]
# ## Integrantes del equipo:
# * Alejandra Elizabeth Trujillo Navarro
# * Carla Georgina Sanchez Arreguin
# * Jessica Montserrat Morales Enrique
# * Sofia Daniela Rodriguez Saenz

# %% [markdown]
# # 1. Proyecto: IT Salary Survey for EU region
# **Dataset:** https://www.kaggle.com/datasets/parulpandey/2020-it-salary-survey-for-eu-region
# <br/>
# <br/>
# <div style="text-align: center;">
#     <img src="images/img212.png" width="400" height="400" alt="image">
#     <img src="images/img213.png" width="339" height="339" alt="image">
# </div>

# %% [markdown]
# ## 2.1 Objetivos general:
# Analizar las tendencias y dinámicas laborales en el sector tecnológico a lo largo del tiempo y en función de diversos factores demográficos, económicos y empresariales, con el fin de proporcionar una visión integral de los cambios en la utilización de tecnologías, estructuras salariales, y decisiones empresariales durante y después de la pandemia de COVID-19

# %% [markdown]
# ## 2.2 Objetivos Específicos del Proyecto
#
# ### 2.2.1. Análisis de lenguajes de programación por grupo de edad
#
# - **Objetivo:** Determinar los lenguajes de programación más utilizados por las siguientes franjas etarias:
#   - 18 a 30 años
#   - 31 a 40 años
#   - Mayores de 41 años
#
# ### 2.2.2. Examinación de estructuras salariales en el sector tecnológico
# - **Objetivo:** Compilar un listado de salarios, ordenados de mayor a menor, especificando el puesto y la ciudad de trabajo.
#
# ### 2.2.3. Identificación de empresas con despidos durante la pandemia de COVID-19
# - **Objetivo:** Listar las empresas que realizaron despidos durante la pandemia y analizar las diferencias salariales entre géneros durante este periodo.
#
# ### 2.2.4. Investigación de lenguajes de programación predominantes
# - **Objetivo:** Establecer cuáles son los lenguajes de programación más utilizados en la actualidad dentro del sector tecnológico.
#
# ### 2.2.5. Estudio de diferencias en empleo y salarios por género
# - **Objetivo:** Comparar las diferencia salariales en trabajadores en los diferentes géneros.
#
# ### 2.2.6. Comparación de salarios anuales de desarrolladores de Python (2018 vs. 2020)
# - **Objetivo:** Analizar cómo han evolucionado los salarios anuales de los desarrolladores de Python desde 2018 hasta 2020.
#
# ### 2.2.7. Evaluación de la evolución de los lenguajes de programación más utilizados (2018-2020)
# - **Objetivo:** Identificar los cinco lenguajes de programación más populares en los años 2018, 2019 y 2020 y examinar las tendencias y cambios a lo largo de estos años.

# %% [markdown]
# ## 1. Etapa 1: 1. Conceptos básicos estructurados de PySpark con DataFrames
# En esta etapa, se concentrará en cargar los datos en HDFS y usar Spark DataFrames para realizar operaciones básicas como crear esquemas, seleccionar columnas, filtrar y ordenar filas y limpieza de valores nulos.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/grafica.png" width="300" height="300" alt="image">
# </div>

# %% [markdown]
# ## 1.1 Código

# %%
# Importamos módulos para la carga y manejo de datos
import pyspark.sql.functions as f 
import pyspark.sql.types as t

# %%
# Creamos sesión de Spark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("IT_Salary") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/16 18:11:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Cargamos los datos de 2018
datasets_path = 'data/'
dataset2018_path=f'{datasets_path}/IT Salary Survey EU 2018.csv'
salaries2018 = spark.read.format('csv').option('header', True).load(dataset2018_path)

# %%
#Renombramos columnas para un mejor manejo de los datos
salaries2018 = salaries2018.withColumnRenamed('Total years of experience', 'YearsExperience'
).withColumnRenamed('Years of experience in Germany', 'YersExpGermany'  
).withColumnRenamed('Seniority Level', 'SeniorityLevel' 
).withColumnRenamed('Your main technology / programming language' , 'ProgrammingLanguage'
).withColumnRenamed('Other technologies/programming languages you use often', 'OtherTech'
).withColumnRenamed('Yearly brutto salary (without bonus and stocks) in EUR', 'YearSalary'
).withColumnRenamed('Yearly bonus + stocks in EUR', 'YearBonus'
).withColumnRenamed('Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country', 'PrevYearSalary'
).withColumnRenamed('Annual bonus+stocks one year ago. Only answer if staying in same country','PrevYearBonus'                   
).withColumnRenamed('Number of vacation days', 'VacationsDays'
).withColumnRenamed('Employment status', 'EmployStatus'
).withColumnRenamed('Сontract duration', 'СontractDuration' 
).withColumnRenamed('Main language at work', 'MainLanguage' 
).withColumnRenamed('Company size', 'CompanySize' 
).withColumnRenamed('Have you lost your job due to the coronavirus outbreak?', 'LostJobCoronavirus'
).withColumnRenamed('Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week', 'ShorterWorkingWeek'  
).withColumnRenamed('Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR', 'PayWorkHome'                    
)

# %%
salaries2018.show(truncate=False, vertical=True)
# Out:
# -RECORD 0--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:41:33
#  Age                                | 43
#  Gender                             | M
#  City                               | München
#  Position                           | QA Ingenieur
#  Years of experience                | 11
#  Your level                         | Senior
#  Current Salary                     | 77000
#  Salary one year ago                | 76200
#  Salary two years ago               | 68000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 100-1000
#  Company type                       | Product
# -RECORD 1--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:42:09
#  Age                                | 33
#  Gender                             | F
#  City                               | München
#  Position                           | Senior PHP Magento developer
#  Years of experience                | 8
#  Your level                         | Senior
#  Current Salary                     | 65000
#  Salary one year ago                | 55000
#  Salary two years ago               | 55000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 50-100
#  Company type                       | Product
# -RECORD 2--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:47:36
#  Age                                | 32
#  Gender                             | M
#  City                               | München
#  Position                           | Software Engineer
#  Years of experience                | 10
#  Your level                         | Senior
#  Current Salary                     | 88000
#  Salary one year ago                | 73000
#  Salary two years ago               | 54000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 3--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:50:15
#  Age                                | 25
#  Gender                             | M
#  City                               | München
#  Position                           | Senior Frontend Developer
#  Years of experience                | 6
#  Your level                         | Senior
#  Current Salary                     | 78000
#  Salary one year ago                | 55000
#  Salary two years ago               | 45000
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | English
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 4--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:50:31
#  Age                                | 39
#  Gender                             | M
#  City                               | München
#  Position                           | UX Designer
#  Years of experience                | 10
#  Your level                         | Senior
#  Current Salary                     | 69000
#  Salary one year ago                | 60000
#  Salary two years ago               | 52000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Ecom retailer
# -RECORD 5--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:52:24
#  Age                                | 37
#  Gender                             | M
#  City                               | München
#  Position                           | Project Manager
#  Years of experience                | 8
#  Your level                         | Senior
#  Current Salary                     | 98000
#  Salary one year ago                | 96000
#  Salary two years ago               | 96000
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | Deutsch
#  CompanySize                        | 1000+
#  Company type                       | Insurance
# -RECORD 6--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:53:47
#  Age                                | NULL
#  Gender                             | M
#  City                               | Berlin
#  Position                           | Senior Android Developer
#  Years of experience                | 5
#  Your level                         | Senior
#  Current Salary                     | 65000
#  Salary one year ago                | 50000
#  Salary two years ago               | 50000
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | English
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 7--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:53:47
#  Age                                | 36
#  Gender                             | F
#  City                               | München
#  Position                           | Data science team lead
#  Years of experience                | 8
#  Your level                         | Senior
#  Current Salary                     | 109000
#  Salary one year ago                | 105000
#  Salary two years ago               | 97000
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | English
#  CompanySize                        | 1000+
#  Company type                       | NULL
# -RECORD 8--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:54:20
#  Age                                | 32
#  Gender                             | M
#  City                               | Berlin
#  Position                           | Test Automation Engineer
#  Years of experience                | 3
#  Your level                         | Senior
#  Current Salary                     | 65000
#  Salary one year ago                | 58000
#  Salary two years ago               | 50000
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Startup
# -RECORD 9--------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:55:44
#  Age                                | 30
#  Gender                             | M
#  City                               | München
#  Position                           | Frontend Developer
#  Years of experience                | 8
#  Your level                         | Senior
#  Current Salary                     | 60000
#  Salary one year ago                | 48000
#  Salary two years ago               | 42000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 100-1000
#  Company type                       | Agency
# -RECORD 10-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:56:28
#  Age                                | 40
#  Gender                             | M
#  City                               | Berlin
#  Position                           | Software Engineer
#  Years of experience                | 18
#  Your level                         | Senior
#  Current Salary                     | 70000
#  Salary one year ago                | 57500
#  Salary two years ago               | 54000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Product
# -RECORD 11-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:56:31
#  Age                                | 33
#  Gender                             | M
#  City                               | Karlsruhe
#  Position                           | Senior Full-stack .Net Developer
#  Years of experience                | 8
#  Your level                         | Senior
#  Current Salary                     | 70000
#  Salary one year ago                | 66000
#  Salary two years ago               | 48000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Product
# -RECORD 12-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 12:59:58
#  Age                                | 31
#  Gender                             | F
#  City                               | Berlin
#  Position                           | QA Lead
#  Years of experience                | NULL
#  Your level                         | Senior
#  Current Salary                     | 55000
#  Salary one year ago                | NULL
#  Salary two years ago               | NULL
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 10-50
#  Company type                       | Startup
# -RECORD 13-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:00:13
#  Age                                | 29
#  Gender                             | M
#  City                               | Berlin
#  Position                           | Front-end engineer
#  Years of experience                | 6
#  Your level                         | Middle
#  Current Salary                     | 55000
#  Salary one year ago                | 55000
#  Salary two years ago               | 34000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Product
# -RECORD 14-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:03:34
#  Age                                | 32
#  Gender                             | M
#  City                               | München
#  Position                           | Software Developer
#  Years of experience                | 11
#  Your level                         | Middle
#  Current Salary                     | 94500
#  Salary one year ago                | 91300
#  Salary two years ago               | 86300
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Russian
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 15-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:06:18
#  Age                                | 25
#  Gender                             | F
#  City                               | München
#  Position                           | QA Test Engineer
#  Years of experience                | 3
#  Your level                         | Junior
#  Current Salary                     | 46000
#  Salary one year ago                | 44000
#  Salary two years ago               | 44000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 100-1000
#  Company type                       | Startup
# -RECORD 16-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:07:09
#  Age                                | 33
#  Gender                             | M
#  City                               | München
#  Position                           | QA Manager
#  Years of experience                | 11
#  Your level                         | Senior
#  Current Salary                     | 68000
#  Salary one year ago                | 65000
#  Salary two years ago               | 63000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 17-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:10:26
#  Age                                | 24
#  Gender                             | M
#  City                               | Hamburg
#  Position                           | Software Engineer
#  Years of experience                | 4
#  Your level                         | Middle
#  Current Salary                     | 60000
#  Salary one year ago                | 47000
#  Salary two years ago               | NULL
#  Are you getting any Stock Options? | No
#  MainLanguage                       | English
#  CompanySize                        | 1000+
#  Company type                       | Product
# -RECORD 18-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:16:09
#  Age                                | 44
#  Gender                             | M
#  City                               | Berlin
#  Position                           | Frontend Developer
#  Years of experience                | 17
#  Your level                         | Senior
#  Current Salary                     | 62500
#  Salary one year ago                | 62500
#  Salary two years ago               | 54000
#  Are you getting any Stock Options? | No
#  MainLanguage                       | Deutsch
#  CompanySize                        | 10-50
#  Company type                       | Agency
# -RECORD 19-------------------------------------------------------------
#  Timestamp                          | 14/12/2018 13:20:36
#  Age                                | 37
#  Gender                             | M
#  City                               | Berlin
#  Position                           | CTO
#  Years of experience                | 19
#  Your level                         | Senior
#  Current Salary                     | 80000
#  Salary one year ago                | 70000
#  Salary two years ago               | NULL
#  Are you getting any Stock Options? | Yes
#  MainLanguage                       | English
#  CompanySize                        | 50-100
#  Company type                       | Startup
# only showing top 20 rows

# %%
# Cargamos los datos de 2019
dataset2019_path=f'{datasets_path}/IT Salary Survey EU 2019.csv'
salaries2019 = spark.read.format('csv').option('header', True).load(dataset2019_path)

# %%
#Renombramos columnas para un mejor manejo de los datos
salaries2019 = salaries2019.withColumnRenamed('Total years of experience', 'YearsExperience'
).withColumnRenamed('Years of experience in Germany', 'YersExpGermany'  
).withColumnRenamed('Seniority Level', 'SeniorityLevel' 
).withColumnRenamed('Your main technology / programming language' , 'ProgrammingLanguage'
).withColumnRenamed('Other technologies/programming languages you use often', 'OtherTech'
).withColumnRenamed('Yearly brutto salary (without bonus and stocks) in EUR', 'YearSalary'
).withColumnRenamed('Yearly bonus + stocks in EUR', 'YearBonus'
).withColumnRenamed('Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country', 'PrevYearSalary'
).withColumnRenamed('Annual bonus+stocks one year ago. Only answer if staying in same country','PrevYearBonus'                   
).withColumnRenamed('Number of vacation days', 'VacationsDays'
).withColumnRenamed('Employment status', 'EmployStatus'
).withColumnRenamed('Сontract duration', 'СontractDuration' 
).withColumnRenamed('Main language at work', 'MainLanguage' 
).withColumnRenamed('Company size', 'CompanySize' 
).withColumnRenamed('Have you lost your job due to the coronavirus outbreak?', 'LostJobCoronavirus'
).withColumnRenamed('Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week', 'ShorterWorkingWeek'  
).withColumnRenamed('Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR', 'PayWorkHome'                    
)

# %%
#Mostramos los datos 2019
salaries2019.show(truncate=False, vertical = True)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:18:26
#  Age                                                                                                  | 33
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Fullstack Developer
#  Years of experience                                                                                  | 13
#  ProgrammingLanguage                                                                                  | PHP
#  Yearly brutto salary (without bonus and stocks)                                                      | 64000
#  Yearly bonus                                                                                         | 1000
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 58000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | 1000
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 29
#  Number of home office days per month                                                                 | 4
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 50-100
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Tourism
#  0                                                                                                    | NULL
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:18:35
#  Age                                                                                                  | 29
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Middle
#  Position (without seniority)                                                                         | Backend Developer
#  Years of experience                                                                                  | 3
#  ProgrammingLanguage                                                                                  | Python
#  Yearly brutto salary (without bonus and stocks)                                                      | 55000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 55000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 22
#  Number of home office days per month                                                                 | 4
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 10-50
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Scientific Activities
#  0                                                                                                    | NULL
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:18:56
#  Age                                                                                                  | NULL
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Middle
#  Position (without seniority)                                                                         | Mobile Developer
#  Years of experience                                                                                  | 4
#  ProgrammingLanguage                                                                                  | Kotlin
#  Yearly brutto salary (without bonus and stocks)                                                      | 70000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 55000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 27
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 1000+
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | NULL
#  0                                                                                                    | NULL
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:19:08
#  Age                                                                                                  | 30
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Backend Developer
#  Years of experience                                                                                  | 6
#  ProgrammingLanguage                                                                                  | PHP
#  Yearly brutto salary (without bonus and stocks)                                                      | 63000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | NULL
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 24
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Auto1
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Transport
#  0                                                                                                    | NULL
# -RECORD 4----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:19:37
#  Age                                                                                                  | 32
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Embedded Developer
#  Years of experience                                                                                  | 10
#  ProgrammingLanguage                                                                                  | C/C++
#  Yearly brutto salary (without bonus and stocks)                                                      | 66000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 56000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 30
#  Number of home office days per month                                                                 | 0
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Luxoft
#  CompanySize                                                                                          | 50-100
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Automotive
#  0                                                                                                    | NULL
# -RECORD 5----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:20:30
#  Age                                                                                                  | 33
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Middle
#  Position (without seniority)                                                                         | Machine Learning Engineer
#  Years of experience                                                                                  | 11
#  ProgrammingLanguage                                                                                  | Python
#  Yearly brutto salary (without bonus and stocks)                                                      | 80000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 75000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 27
#  Number of home office days per month                                                                 | 5
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Zalando
#  CompanySize                                                                                          | 1000+
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Сommerce
#  0                                                                                                    | NULL
# -RECORD 6----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:21:26
#  Age                                                                                                  | 34
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Backend Developer
#  Years of experience                                                                                  | 12
#  ProgrammingLanguage                                                                                  | Java
#  Yearly brutto salary (without bonus and stocks)                                                      | 85000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 76000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 25
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 50-100
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | NULL
#  0                                                                                                    | NULL
# -RECORD 7----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:21:31
#  Age                                                                                                  | 38
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Head
#  Position (without seniority)                                                                         | Manager
#  Years of experience                                                                                  | 15
#  ProgrammingLanguage                                                                                  | Not Relevant
#  Yearly brutto salary (without bonus and stocks)                                                      | 81000
#  Yearly bonus                                                                                         | 4000
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 75000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 30
#  Number of home office days per month                                                                 | 10
#  MainLanguage                                                                                         | Deutsch
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Automotive
#  0                                                                                                    | NULL
# -RECORD 8----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:21:38
#  Age                                                                                                  | NULL
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Lead
#  Position (without seniority)                                                                         | Mobile Developer
#  Years of experience                                                                                  | 8
#  ProgrammingLanguage                                                                                  | Swift
#  Yearly brutto salary (without bonus and stocks)                                                      | 66000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 63000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 28
#  Number of home office days per month                                                                 | 15
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Coaching
#  0                                                                                                    | NULL
# -RECORD 9----------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:21:52
#  Age                                                                                                  | 29
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Mobile Developer
#  Years of experience                                                                                  | 7
#  ProgrammingLanguage                                                                                  | Kotlin
#  Yearly brutto salary (without bonus and stocks)                                                      | 65000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 54000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 26
#  Number of home office days per month                                                                 | 4
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Bonial International GmbH
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Сommerce
#  0                                                                                                    | NULL
# -RECORD 10---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:21:55
#  Age                                                                                                  | 27
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Middle
#  Position (without seniority)                                                                         | Fullstack Developer
#  Years of experience                                                                                  | 7
#  ProgrammingLanguage                                                                                  | Javascript / Typescript
#  Yearly brutto salary (without bonus and stocks)                                                      | 63000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 60000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 28
#  Number of home office days per month                                                                 | 1
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 10-50
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Finance / Insurance
#  0                                                                                                    | NULL
# -RECORD 11---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:22:36
#  Age                                                                                                  | 31
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Backend Developer
#  Years of experience                                                                                  | 8
#  ProgrammingLanguage                                                                                  | Go
#  Yearly brutto salary (without bonus and stocks)                                                      | 65000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | NULL
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 26
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Football app
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | 6 months
#  Company business sector                                                                              | Gaming
#  0                                                                                                    | NULL
# -RECORD 12---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:22:43
#  Age                                                                                                  | 23
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | DevOps
#  Years of experience                                                                                  | 6
#  ProgrammingLanguage                                                                                  | AWS
#  Yearly brutto salary (without bonus and stocks)                                                      | 83000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 63000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 30
#  Number of home office days per month                                                                 | 1
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Digital service for one-man-business craftsmen
#  CompanySize                                                                                          | 10-50
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Manufacture
#  0                                                                                                    | NULL
# -RECORD 13---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:23:23
#  Age                                                                                                  | 27
# ...
#  VacationsDays                                                                                        | 26
#  Number of home office days per month                                                                 | 4
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Startup
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Transport
#  0                                                                                                    | NULL
# -RECORD 16---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:24:53
#  Age                                                                                                  | 31
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Middle
#  Position (without seniority)                                                                         | Mobile Developer
#  Years of experience                                                                                  | 6
#  ProgrammingLanguage                                                                                  | Swift
#  Yearly brutto salary (without bonus and stocks)                                                      | 72000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 70000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 27
#  Number of home office days per month                                                                 | 0
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | Omio
#  CompanySize                                                                                          | 100-1000
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Сommerce
#  0                                                                                                    | NULL
# -RECORD 17---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:24:54
#  Age                                                                                                  | 34
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Backend Developer
#  Years of experience                                                                                  | 10
#  ProgrammingLanguage                                                                                  | Java
#  Yearly brutto salary (without bonus and stocks)                                                      | 87000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | NULL
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 28
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 50-100
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Advertising
#  0                                                                                                    | NULL
# -RECORD 18---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:25:24
#  Age                                                                                                  | 33
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | DevOps
#  Years of experience                                                                                  | 12
#  ProgrammingLanguage                                                                                  | Kubernetes
#  Yearly brutto salary (without bonus and stocks)                                                      | 90000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 84000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | 30
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 1000+
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Сommerce
#  0                                                                                                    | NULL
# -RECORD 19---------------------------------------------------------------------------------------------------------------------------------------------
#  Zeitstempel                                                                                          | 02.12.2019 11:25:36
#  Age                                                                                                  | 31
#  Gender                                                                                               | Male
#  City                                                                                                 | Berlin
#  SeniorityLevel                                                                                       | Senior
#  Position (without seniority)                                                                         | Data Scientist
#  Years of experience                                                                                  | 6
#  ProgrammingLanguage                                                                                  | Python
#  Yearly brutto salary (without bonus and stocks)                                                      | 78000
#  Yearly bonus                                                                                         | NULL
#  Yearly stocks                                                                                        | NULL
#  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country | 76000
#  Yearly bonus one year ago. Only answer if staying in same country                                    | NULL
#  Yearly stocks one year ago. Only answer if staying in same country                                   | NULL
#  VacationsDays                                                                                        | NULL
#  Number of home office days per month                                                                 | NULL
#  MainLanguage                                                                                         | English
#  Company name                                                                                         | NULL
#  CompanySize                                                                                          | 1000+
#  Company type                                                                                         | Product
#  СontractDuration                                                                                     | unlimited
#  Company business sector                                                                              | Сommerce
#  0                                                                                                    | NULL
# only showing top 20 rows

# %%
# Cargamos los datos de 2020
datasets_path = 'data/'
dataset2020_path=f'{datasets_path}/IT Salary Survey EU 2020.csv'
salaries2020 = spark.read.format('csv').option('header', True).load(dataset2020_path)

# %%
#Renombramos columnas para un mejor manejo de los datos
salaries2020 = salaries2020.withColumnRenamed('Total years of experience', 'YearsExperience'
).withColumnRenamed('Years of experience in Germany', 'YersExpGermany'  
).withColumnRenamed('Seniority Level', 'SeniorityLevel' 
).withColumnRenamed('Your main technology / programming language' , 'ProgrammingLanguage'
).withColumnRenamed('Other technologies/programming languages you use often', 'OtherTech'
).withColumnRenamed('Yearly brutto salary (without bonus and stocks) in EUR', 'YearSalary'
).withColumnRenamed('Yearly bonus + stocks in EUR', 'YearBonus'
).withColumnRenamed('Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country', 'PrevYearSalary'
).withColumnRenamed('Annual bonus+stocks one year ago. Only answer if staying in same country','PrevYearBonus'                   
).withColumnRenamed('Number of vacation days', 'VacationsDays'
).withColumnRenamed('Employment status', 'EmployStatus'
).withColumnRenamed('Сontract duration', 'СontractDuration' 
).withColumnRenamed('Main language at work', 'MainLanguage' 
).withColumnRenamed('Company size', 'CompanySize' 
).withColumnRenamed('Have you lost your job due to the coronavirus outbreak?', 'LostJobCoronavirus'
).withColumnRenamed('Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week', 'ShorterWorkingWeek'  
).withColumnRenamed('Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR', 'PayWorkHome'                    
)

# %%
#Mostramos los datos 2020
salaries2020.show(truncate=False, vertical = True)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:14:15
#  Age                 | 26
#  Gender              | Male
#  City                | Munich
#  Position            | Software Engineer
#  YearsExperience     | 5
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | TypeScript
#  OtherTech           | Kotlin, Javascript / Typescript
#  YearSalary          | 80000
#  YearBonus           | 5000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 10000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 1-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:14:16
#  Age                 | 26
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 4
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Ruby
#  OtherTech           | NULL
#  YearSalary          | 80000
#  YearBonus           | NULL
#  PrevYearSalary      | 82000
#  PrevYearBonus       | 5000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 2-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:14:21
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 12
#  YersExpGermany      | 6
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Javascript / Typescript
#  OtherTech           | Javascript / Typescript, Docker
#  YearSalary          | 120000
#  YearBonus           | 120000
#  PrevYearSalary      | 100000
#  PrevYearBonus       | 100000
#  VacationsDays       | 30
#  EmployStatus        | Self-employed (freelancer)
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 3-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:15:24
#  Age                 | 28
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 4
#  YersExpGermany      | 1
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 54000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 4-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:15:46
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 17
#  YersExpGermany      | 6
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C# .NET
#  OtherTech           | .NET, SQL, AWS, Docker
#  YearSalary          | 62000
#  YearBonus           | NULL
#  PrevYearSalary      | 62000
#  PrevYearBonus       | NULL
#  VacationsDays       | 29
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 5-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:15:53
#  Age                 | 32
#  Gender              | Male
#  City                | Berlin
#  Position            | DevOps
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | AWS, GCP, Python,K8s
#  OtherTech           | Python, AWS, Google Cloud, Kubernetes, Docker
#  YearSalary          | 76000
#  YearBonus           | 5000
#  PrevYearSalary      | 76000
#  PrevYearBonus       | 5000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 6-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:16:35
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 6
#  YersExpGermany      | 0.4
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 57000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 7-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:16:44
#  Age                 | 24
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | Javascript / Typescript
#  YearSalary          | 65000
#  YearBonus           | NULL
#  PrevYearSalary      | 65000
#  PrevYearBonus       | NULL
#  VacationsDays       | 27
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | 600
# -RECORD 8-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:17:24
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | SQL, AWS, Docker
#  YearSalary          | 56000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 30
#  PayWorkHome         | NULL
# -RECORD 9-------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:17:50
#  Age                 | 35
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 15
#  YersExpGermany      | 3
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Java
#  OtherTech           | NULL
#  YearSalary          | 95000
#  YearBonus           | NULL
#  PrevYearSalary      | 90000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 10------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:06
#  Age                 | 32
#  Gender              | Female
#  City                | Hamburg
#  Position            | Data Engineer
#  YearsExperience     | 2
#  YersExpGermany      | 2
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Aws Hadoop Postgre Typescript
#  OtherTech           | Python, Kotlin, Javascript / Typescript, SQL, AWS
#  YearSalary          | 52500
#  YearBonus           | NULL
#  PrevYearSalary      | 52500
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | German
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 11------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:16
#  Age                 | NULL
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 25
#  YersExpGermany      | 11
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C++
#  OtherTech           | Python, C/C++, SQL
#  YearSalary          | 100000
#  YearBonus           | 101
#  PrevYearSalary      | 80000
#  PrevYearBonus       | 13000
#  VacationsDays       | 24
#  EmployStatus        | Self-employed (freelancer)
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 12------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:22
#  Age                 | NULL
#  Gender              | NULL
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | NULL
#  YersExpGermany      | NULL
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | PHP
#  OtherTech           | NULL
#  YearSalary          | 90000
#  YearBonus           | 40000
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | NULL
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | NULL
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | 1000
# -RECORD 13------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:26
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 14
#  YersExpGermany      | 5
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | PHP, Javascript / Typescript, AWS
#  YearSalary          | 70000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 14------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:40
#  Age                 | 28
#  Gender              | Male
#  City                | Berlin
#  Position            | Designer (UI/UX)
#  YearsExperience     | 11
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | NULL
#  OtherTech           | NULL
#  YearSalary          | 75000
#  YearBonus           | 9400
#  PrevYearSalary      | 66000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 15------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:41
#  Age                 | 31
#  Gender              | Male
#  City                | Wolfsburg
#  Position            | Backend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Kotlin
#  OtherTech           | NULL
#  YearSalary          | 75000
#  YearBonus           | 2000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 2000
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 16------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:18:52
#  Age                 | 29
#  Gender              | Male
#  City                | Hamburg
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 3
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Ruby
#  OtherTech           | Go, Kubernetes, Docker
#  YearSalary          | 60350
#  YearBonus           | NULL
#  PrevYearSalary      | 58000
#  PrevYearBonus       | 500
#  VacationsDays       | 31
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | i didn't but will be looking for new one because of covid
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 17------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:19:10
#  Age                 | 41
#  Gender              | Male
#  City                | Berlin
#  Position            | Product Manager
#  YearsExperience     | 18
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | NULL
#  OtherTech           | SQL
#  YearSalary          | 78000
#  YearBonus           | NULL
#  PrevYearSalary      | 100000
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Startup
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 18------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:20:03
#  Age                 | 27
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | NULL
#  YearSalary          | 60000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 19------------------------------------------------------------------------------------
#  Timestamp           | 24/11/2020 11:20:49
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Mobile Developer
#  YearsExperience     | 11
#  YersExpGermany      | 5
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | kotlin
#  OtherTech           | Kotlin, Javascript / Typescript, AWS, Google Cloud, Kubernetes, Docker
#  YearSalary          | 80000
#  YearBonus           | 80000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 75000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# only showing top 20 rows

# %% [markdown]
# ## 2. Etapa 2: Análisis de datos con PySpark Estructurado
# En esta etapa, utilizarás Spark DataFrames para realizar análisis de datos y obtener información.
# Utilizarás agregaciones y estadísticas de dataframe para responder preguntas sobre los datos.
# También puedes utilizar visualizaciones para mostrar tus resultados

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/analysis.png" width="500" height="200" alt="image">
# </div>

# %% [markdown]
# ## 2.1 Código

# %% [markdown]
# ### 2.1.1. Investigación de lenguajes de programación predominantes
# En esta sección, realizaremos un análisis de los lenguajes de programación más utilizados en el año 2020 en la empresas alemanas.

# %%
### Verificamos estructura de los salarios
salaries2020.printSchema()
# Out:
# root
#  |-- Timestamp: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Position : string (nullable = true)
#  |-- YearsExperience: string (nullable = true)
#  |-- YersExpGermany: string (nullable = true)
#  |-- SeniorityLevel: string (nullable = true)
#  |-- ProgrammingLanguage: string (nullable = true)
#  |-- OtherTech: string (nullable = true)
#  |-- YearSalary: string (nullable = true)
#  |-- YearBonus: string (nullable = true)
#  |-- PrevYearSalary: string (nullable = true)
#  |-- PrevYearBonus: string (nullable = true)
#  |-- VacationsDays: string (nullable = true)
#  |-- EmployStatus: string (nullable = true)
#  |-- СontractDuration: string (nullable = true)
#  |-- MainLanguage: string (nullable = true)
#  |-- CompanySize: string (nullable = true)
#  |-- Company type: string (nullable = true)
#  |-- LostJobCoronavirus: string (nullable = true)
#  |-- ShorterWorkingWeek: string (nullable = true)
#  |-- PayWorkHome: string (nullable = true)

# %%
# Usaremos la columna de ProgrammingLanguage
#Eliminamos aquellos registros vacios en las columnas de interes
from pyspark.sql.functions import col

# Eliminar los registros con valores nulos en las columnas de interés
salaries2020_clean = salaries2020.filter(
    col('ProgrammingLanguage').isNotNull() 
)

# Mostrar los primeros registros para verificar
salaries2020_clean.show(truncate=True, vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  Timestamp           | 24/11/2020 11:14:15
#  Age                 | 26
#  Gender              | Male
#  City                | Munich
#  Position            | Software Engineer
#  YearsExperience     | 5
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | TypeScript
#  OtherTech           | Kotlin, Javascrip...
#  YearSalary          | 80000
#  YearBonus           | 5000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 10000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 1-----------------------------------
#  Timestamp           | 24/11/2020 11:14:16
#  Age                 | 26
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 4
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Ruby
#  OtherTech           | NULL
#  YearSalary          | 80000
#  YearBonus           | NULL
#  PrevYearSalary      | 82000
#  PrevYearBonus       | 5000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 2-----------------------------------
#  Timestamp           | 24/11/2020 11:14:21
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 12
#  YersExpGermany      | 6
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Javascript / Type...
#  OtherTech           | Javascript / Type...
#  YearSalary          | 120000
#  YearBonus           | 120000
#  PrevYearSalary      | 100000
#  PrevYearBonus       | 100000
#  VacationsDays       | 30
#  EmployStatus        | Self-employed (fr...
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 3-----------------------------------
#  Timestamp           | 24/11/2020 11:15:24
#  Age                 | 28
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 4
#  YersExpGermany      | 1
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 54000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 4-----------------------------------
#  Timestamp           | 24/11/2020 11:15:46
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 17
#  YersExpGermany      | 6
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C# .NET
#  OtherTech           | .NET, SQL, AWS, D...
#  YearSalary          | 62000
#  YearBonus           | NULL
#  PrevYearSalary      | 62000
#  PrevYearBonus       | NULL
#  VacationsDays       | 29
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 5-----------------------------------
#  Timestamp           | 24/11/2020 11:15:53
#  Age                 | 32
#  Gender              | Male
#  City                | Berlin
#  Position            | DevOps
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | AWS, GCP, Python,K8s
#  OtherTech           | Python, AWS, Goog...
#  YearSalary          | 76000
#  YearBonus           | 5000
#  PrevYearSalary      | 76000
#  PrevYearBonus       | 5000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 6-----------------------------------
#  Timestamp           | 24/11/2020 11:16:35
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 6
#  YersExpGermany      | 0.4
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 57000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 7-----------------------------------
#  Timestamp           | 24/11/2020 11:16:44
#  Age                 | 24
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | Javascript / Type...
#  YearSalary          | 65000
#  YearBonus           | NULL
#  PrevYearSalary      | 65000
#  PrevYearBonus       | NULL
#  VacationsDays       | 27
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | 600
# -RECORD 8-----------------------------------
#  Timestamp           | 24/11/2020 11:17:24
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | SQL, AWS, Docker
#  YearSalary          | 56000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 30
#  PayWorkHome         | NULL
# -RECORD 9-----------------------------------
#  Timestamp           | 24/11/2020 11:17:50
#  Age                 | 35
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 15
#  YersExpGermany      | 3
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Java
#  OtherTech           | NULL
#  YearSalary          | 95000
#  YearBonus           | NULL
#  PrevYearSalary      | 90000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 10----------------------------------
#  Timestamp           | 24/11/2020 11:18:06
#  Age                 | 32
#  Gender              | Female
#  City                | Hamburg
#  Position            | Data Engineer
#  YearsExperience     | 2
#  YersExpGermany      | 2
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Aws Hadoop Postgr...
#  OtherTech           | Python, Kotlin, J...
#  YearSalary          | 52500
#  YearBonus           | NULL
#  PrevYearSalary      | 52500
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | German
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 11----------------------------------
#  Timestamp           | 24/11/2020 11:18:16
#  Age                 | NULL
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 25
#  YersExpGermany      | 11
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C++
#  OtherTech           | Python, C/C++, SQL
#  YearSalary          | 100000
#  YearBonus           | 101
#  PrevYearSalary      | 80000
#  PrevYearBonus       | 13000
#  VacationsDays       | 24
#  EmployStatus        | Self-employed (fr...
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 12----------------------------------
#  Timestamp           | 24/11/2020 11:18:22
#  Age                 | NULL
#  Gender              | NULL
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | NULL
#  YersExpGermany      | NULL
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | PHP
#  OtherTech           | NULL
#  YearSalary          | 90000
#  YearBonus           | 40000
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | NULL
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | NULL
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | 1000
# -RECORD 13----------------------------------
#  Timestamp           | 24/11/2020 11:18:26
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 14
#  YersExpGermany      | 5
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | PHP, Javascript /...
#  YearSalary          | 70000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 14----------------------------------
#  Timestamp           | 24/11/2020 11:18:41
#  Age                 | 31
#  Gender              | Male
#  City                | Wolfsburg
#  Position            | Backend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Kotlin
#  OtherTech           | NULL
#  YearSalary          | 75000
#  YearBonus           | 2000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 2000
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 15----------------------------------
#  Timestamp           | 24/11/2020 11:18:52
#  Age                 | 29
#  Gender              | Male
#  City                | Hamburg
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 3
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Ruby
#  OtherTech           | Go, Kubernetes, D...
#  YearSalary          | 60350
#  YearBonus           | NULL
#  PrevYearSalary      | 58000
#  PrevYearBonus       | 500
#  VacationsDays       | 31
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | i didn't but will...
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 16----------------------------------
#  Timestamp           | 24/11/2020 11:20:03
#  Age                 | 27
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | NULL
#  YearSalary          | 60000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 17----------------------------------
#  Timestamp           | 24/11/2020 11:20:49
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Mobile Developer
#  YearsExperience     | 11
#  YersExpGermany      | 5
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | kotlin
#  OtherTech           | Kotlin, Javascrip...
#  YearSalary          | 80000
#  YearBonus           | 80000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 75000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 18----------------------------------
#  Timestamp           | 24/11/2020 11:21:18
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Architect
#  YearsExperience     | 15
#  YersExpGermany      | 9
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | NodeJS
#  OtherTech           | Javascript / Type...
#  YearSalary          | 100000
#  YearBonus           | NULL
#  PrevYearSalary      | 92000
#  PrevYearBonus       | 7000
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 19----------------------------------
#  Timestamp           | 24/11/2020 11:22:57
#  Age                 | 25
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 5
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Javascript
#  OtherTech           | Javascript / Type...
#  YearSalary          | 65000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | German
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# only showing top 20 rows

# %%
#Obtenemos los datos de lenguajes contamos la frecuencia y los ordenamos en orden descendiente
#Primero formateamos los datos mayusculas para evitar repetir mismos lenguajes

language_users = salaries2020_clean.groupBy("ProgrammingLanguage").agg(f.count("ProgrammingLanguage").alias("Users"))
language_users= language_users.orderBy(col("Users").desc())

# %%
#Graficamos los datos
language_users_df= language_users.toPandas()

plt.figure(figsize=(12, 8))
plt.bar(language_users_df["ProgrammingLanguage"][:20], language_users_df["Users"][:20], color='skyblue')
plt.xlabel("Lenguaje de Programación")
plt.ylabel("Frecuencia")
plt.title("Lenguajes de Programación Más Utilizados")
plt.xticks(rotation=45)
plt.show()

# %%
#Grafiacamos los datos
language_counts_pd = language_counts.toPandas()

# Configurar el gráfico de barras
plt.figure(figsize=(12, 8))
plt.bar(language_counts_pd["ProgrammingLanguage"], language_counts_pd["count"], color='skyblue')
plt.xlabel("Lenguaje de Programación")
plt.ylabel("Frecuencia")
plt.title("Lenguajes de Programación Más Utilizados")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 #Grafiacamos los datos
# ----> 2 language_counts_pd = language_counts.toPandas()
#       4 # Configurar el gráfico de barras
#       5 plt.figure(figsize=(12, 8))
#
# NameError: name 'language_counts' is not defined

# %% [markdown]
# ### 2.1.2. Diferencia entre promedios salariales del género masculino y femenino
# En esta sección, exploraremos las diferencias en los salarios entre hombres y mujeres, enfocándonos específicamente en el nivel senior para obtener un análisis detallado de un segmento concreto. Iniciaremos con un análisis descriptivo estadístico para evaluar la forma de los datos.  Para ello, nos enfocaremos en el año mas reciente proporcionado en los datos, es decir 2020.

# %%
### Verificamos estructura de los salarios
salaries2020.printSchema()
# Out:
# root
#  |-- Timestamp: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Position : string (nullable = true)
#  |-- YearsExperience: string (nullable = true)
#  |-- YersExpGermany: string (nullable = true)
#  |-- SeniorityLevel: string (nullable = true)
#  |-- ProgrammingLanguage: string (nullable = true)
#  |-- OtherTech: string (nullable = true)
#  |-- YearSalary: string (nullable = true)
#  |-- YearBonus: string (nullable = true)
#  |-- PrevYearSalary: string (nullable = true)
#  |-- PrevYearBonus: string (nullable = true)
#  |-- VacationsDays: string (nullable = true)
#  |-- EmployStatus: string (nullable = true)
#  |-- СontractDuration: string (nullable = true)
#  |-- MainLanguage: string (nullable = true)
#  |-- CompanySize: string (nullable = true)
#  |-- Company type: string (nullable = true)
#  |-- LostJobCoronavirus: string (nullable = true)
#  |-- ShorterWorkingWeek: string (nullable = true)
#  |-- PayWorkHome: string (nullable = true)

# %%
#Verificamos numero de filas en el archivo
salaries2020.count()
# Out:
# 1253

# %%
# Usaremos las columnas de Gender para filtrar entre hombres y mujeres, YearSalary como medicion del salario y Seniority level para filtrar por experiencia
#Eliminamos aquellos registros vacios en las columnas de interes
# Eliminar los registros con valores nulos en las columnas de interés
salaries2020_clean = salaries2020.filter(
    col('Gender').isNotNull() &
    col('YearSalary').isNotNull() &
    col('SeniorityLevel').isNotNull()
)

# Mostrar los primeros registros para verificar
salaries2020_clean.show(truncate=True, vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  Timestamp           | 24/11/2020 11:14:15
#  Age                 | 26
#  Gender              | Male
#  City                | Munich
#  Position            | Software Engineer
#  YearsExperience     | 5
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | TypeScript
#  OtherTech           | Kotlin, Javascrip...
#  YearSalary          | 80000
#  YearBonus           | 5000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 10000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 1-----------------------------------
#  Timestamp           | 24/11/2020 11:14:16
#  Age                 | 26
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 4
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Ruby
#  OtherTech           | NULL
#  YearSalary          | 80000
#  YearBonus           | NULL
#  PrevYearSalary      | 82000
#  PrevYearBonus       | 5000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 2-----------------------------------
#  Timestamp           | 24/11/2020 11:14:21
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 12
#  YersExpGermany      | 6
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Javascript / Type...
#  OtherTech           | Javascript / Type...
#  YearSalary          | 120000
#  YearBonus           | 120000
#  PrevYearSalary      | 100000
#  PrevYearBonus       | 100000
#  VacationsDays       | 30
#  EmployStatus        | Self-employed (fr...
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 3-----------------------------------
#  Timestamp           | 24/11/2020 11:15:24
#  Age                 | 28
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 4
#  YersExpGermany      | 1
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 54000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 4-----------------------------------
#  Timestamp           | 24/11/2020 11:15:46
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 17
#  YersExpGermany      | 6
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C# .NET
#  OtherTech           | .NET, SQL, AWS, D...
#  YearSalary          | 62000
#  YearBonus           | NULL
#  PrevYearSalary      | 62000
#  PrevYearBonus       | NULL
#  VacationsDays       | 29
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 5-----------------------------------
#  Timestamp           | 24/11/2020 11:15:53
#  Age                 | 32
#  Gender              | Male
#  City                | Berlin
#  Position            | DevOps
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | AWS, GCP, Python,K8s
#  OtherTech           | Python, AWS, Goog...
#  YearSalary          | 76000
#  YearBonus           | 5000
#  PrevYearSalary      | 76000
#  PrevYearBonus       | 5000
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 6-----------------------------------
#  Timestamp           | 24/11/2020 11:16:35
#  Age                 | 37
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 6
#  YersExpGermany      | 0.4
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Javascript
#  OtherTech           | NULL
#  YearSalary          | 57000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 24
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 7-----------------------------------
#  Timestamp           | 24/11/2020 11:16:44
#  Age                 | 24
#  Gender              | Male
#  City                | Berlin
#  Position            | Frontend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | Javascript / Type...
#  YearSalary          | 65000
#  YearBonus           | NULL
#  PrevYearSalary      | 65000
#  PrevYearBonus       | NULL
#  VacationsDays       | 27
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | 600
# -RECORD 8-----------------------------------
#  Timestamp           | 24/11/2020 11:17:24
#  Age                 | 29
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | SQL, AWS, Docker
#  YearSalary          | 56000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 30
#  PayWorkHome         | NULL
# -RECORD 9-----------------------------------
#  Timestamp           | 24/11/2020 11:17:50
#  Age                 | 35
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 15
#  YersExpGermany      | 3
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | Java
#  OtherTech           | NULL
#  YearSalary          | 95000
#  YearBonus           | NULL
#  PrevYearSalary      | 90000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 10----------------------------------
#  Timestamp           | 24/11/2020 11:18:06
#  Age                 | 32
#  Gender              | Female
#  City                | Hamburg
#  Position            | Data Engineer
#  YearsExperience     | 2
#  YersExpGermany      | 2
#  SeniorityLevel      | Junior
#  ProgrammingLanguage | Aws Hadoop Postgr...
#  OtherTech           | Python, Kotlin, J...
#  YearSalary          | 52500
#  YearBonus           | NULL
#  PrevYearSalary      | 52500
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | German
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 11----------------------------------
#  Timestamp           | 24/11/2020 11:18:16
#  Age                 | NULL
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 25
#  YersExpGermany      | 11
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | C++
#  OtherTech           | Python, C/C++, SQL
#  YearSalary          | 100000
#  YearBonus           | 101
#  PrevYearSalary      | 80000
#  PrevYearBonus       | 13000
#  VacationsDays       | 24
#  EmployStatus        | Self-employed (fr...
#  СontractDuration    | Temporary contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 12----------------------------------
#  Timestamp           | 24/11/2020 11:18:26
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Software Engineer
#  YearsExperience     | 14
#  YersExpGermany      | 5
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Typescript
#  OtherTech           | PHP, Javascript /...
#  YearSalary          | 70000
#  YearBonus           | NULL
#  PrevYearSalary      | NULL
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 11-50
#  Company type        | Startup
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 13----------------------------------
#  Timestamp           | 24/11/2020 11:18:40
#  Age                 | 28
#  Gender              | Male
#  City                | Berlin
#  Position            | Designer (UI/UX)
#  YearsExperience     | 11
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | NULL
#  OtherTech           | NULL
#  YearSalary          | 75000
#  YearBonus           | 9400
#  PrevYearSalary      | 66000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 14----------------------------------
#  Timestamp           | 24/11/2020 11:18:41
#  Age                 | 31
#  Gender              | Male
#  City                | Wolfsburg
#  Position            | Backend Developer
#  YearsExperience     | 5
#  YersExpGermany      | 1
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | Kotlin
#  OtherTech           | NULL
#  YearSalary          | 75000
#  YearBonus           | 2000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 2000
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Consulting / Agency
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 15----------------------------------
#  Timestamp           | 24/11/2020 11:18:52
#  Age                 | 29
#  Gender              | Male
#  City                | Hamburg
#  Position            | Backend Developer
#  YearsExperience     | 7
#  YersExpGermany      | 3
#  SeniorityLevel      | Middle
#  ProgrammingLanguage | Ruby
#  OtherTech           | Go, Kubernetes, D...
#  YearSalary          | 60350
#  YearBonus           | NULL
#  PrevYearSalary      | 58000
#  PrevYearBonus       | 500
#  VacationsDays       | 31
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | i didn't but will...
#  ShorterWorkingWeek  | 0
#  PayWorkHome         | NULL
# -RECORD 16----------------------------------
#  Timestamp           | 24/11/2020 11:19:10
#  Age                 | 41
#  Gender              | Male
#  City                | Berlin
#  Position            | Product Manager
#  YearsExperience     | 18
#  YersExpGermany      | 2
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | NULL
#  OtherTech           | SQL
#  YearSalary          | 78000
#  YearBonus           | NULL
#  PrevYearSalary      | 100000
#  PrevYearBonus       | NULL
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 51-100
#  Company type        | Startup
#  LostJobCoronavirus  | Yes
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 17----------------------------------
#  Timestamp           | 24/11/2020 11:20:03
#  Age                 | 27
#  Gender              | Male
#  City                | Berlin
#  Position            | Backend Developer
#  YearsExperience     | 8
#  YersExpGermany      | 3
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | PHP
#  OtherTech           | NULL
#  YearSalary          | 60000
#  YearBonus           | NULL
#  PrevYearSalary      | 55000
#  PrevYearBonus       | NULL
#  VacationsDays       | 25
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 18----------------------------------
#  Timestamp           | 24/11/2020 11:20:49
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | Mobile Developer
#  YearsExperience     | 11
#  YersExpGermany      | 5
#  SeniorityLevel      | Lead
#  ProgrammingLanguage | kotlin
#  OtherTech           | Kotlin, Javascrip...
#  YearSalary          | 80000
#  YearBonus           | 80000
#  PrevYearSalary      | 75000
#  PrevYearBonus       | 75000
#  VacationsDays       | 28
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 101-1000
#  Company type        | Product
#  LostJobCoronavirus  | No
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# -RECORD 19----------------------------------
#  Timestamp           | 24/11/2020 11:21:10
#  Age                 | 34
#  Gender              | Male
#  City                | Berlin
#  Position            | DevOps
#  YearsExperience     | 13
#  YersExpGermany      | 5
#  SeniorityLevel      | Senior
#  ProgrammingLanguage | NULL
#  OtherTech           | NULL
#  YearSalary          | 103000
#  YearBonus           | NULL
#  PrevYearSalary      | 90000
#  PrevYearBonus       | NULL
#  VacationsDays       | 30
#  EmployStatus        | Full-time employee
#  СontractDuration    | Unlimited contract
#  MainLanguage        | English
#  CompanySize         | 1000+
#  Company type        | Product
#  LostJobCoronavirus  | NULL
#  ShorterWorkingWeek  | NULL
#  PayWorkHome         | NULL
# only showing top 20 rows

# %%
#Verificamos numero de filas en el dataframe despues de limpieza
salaries2020_clean.count()
# Out:
# 1235

# %%
#Exploramos los diferentes valores de Seniority level
salaries2020_clean.dropDuplicates(['SeniorityLevel']).select('SeniorityLevel').show(truncate=False, vertical = True)
# Out:
# -RECORD 0---------------------------------------------------
#  SeniorityLevel | Senior
# -RECORD 1---------------------------------------------------
#  SeniorityLevel | VP
# -RECORD 2---------------------------------------------------
#  SeniorityLevel | Student
# -RECORD 3---------------------------------------------------
#  SeniorityLevel | CTO
# -RECORD 4---------------------------------------------------
#  SeniorityLevel | Principal
# -RECORD 5---------------------------------------------------
#  SeniorityLevel | Director
# -RECORD 6---------------------------------------------------
#  SeniorityLevel | intern
# -RECORD 7---------------------------------------------------
#  SeniorityLevel | No level
# -RECORD 8---------------------------------------------------
#  SeniorityLevel | Middle
# -RECORD 9---------------------------------------------------
#  SeniorityLevel | Head
# -RECORD 10--------------------------------------------------
#  SeniorityLevel | C-Level
# -RECORD 11--------------------------------------------------
#  SeniorityLevel | Intern
# -RECORD 12--------------------------------------------------
#  SeniorityLevel | Lead
# -RECORD 13--------------------------------------------------
#  SeniorityLevel | No level
# -RECORD 14--------------------------------------------------
#  SeniorityLevel | Self employed
# -RECORD 15--------------------------------------------------
#  SeniorityLevel | student
# -RECORD 16--------------------------------------------------
#  SeniorityLevel | Entry level
# -RECORD 17--------------------------------------------------
#  SeniorityLevel | C-level executive manager
# -RECORD 18--------------------------------------------------
#  SeniorityLevel | Working Student
# -RECORD 19--------------------------------------------------
#  SeniorityLevel | no idea, there are no ranges in the firm
# only showing top 20 rows

# %%
#Filtramos solo los registros en nivel senior usando SQL
# Registrar el DataFrame como una vista temporal
salaries2020_clean.createOrReplaceTempView("salaries2020_clean")
salaries2020_senior = spark.sql("""
    SELECT * FROM salaries2020_clean WHERE SeniorityLevel = 'Senior'
""")
salaries2020_senior.count()
# Out:
# 562

# %%
salaries2020_senior.printSchema()
# Out:
# root
#  |-- Timestamp: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Position : string (nullable = true)
#  |-- YearsExperience: string (nullable = true)
#  |-- YersExpGermany: string (nullable = true)
#  |-- SeniorityLevel: string (nullable = true)
#  |-- ProgrammingLanguage: string (nullable = true)
#  |-- OtherTech: string (nullable = true)
#  |-- YearSalary: string (nullable = true)
#  |-- YearBonus: string (nullable = true)
#  |-- PrevYearSalary: string (nullable = true)
#  |-- PrevYearBonus: string (nullable = true)
#  |-- VacationsDays: string (nullable = true)
#  |-- EmployStatus: string (nullable = true)
#  |-- СontractDuration: string (nullable = true)
#  |-- MainLanguage: string (nullable = true)
#  |-- CompanySize: string (nullable = true)
#  |-- Company type: string (nullable = true)
#  |-- LostJobCoronavirus: string (nullable = true)
#  |-- ShorterWorkingWeek: string (nullable = true)
#  |-- PayWorkHome: string (nullable = true)

# %%
#Analizamos los datos
salaries2020_senior = salaries2020_senior.withColumn("YearSalary", col("YearSalary").cast("double"))
stats_salaries = salaries2020_senior.select(
    f.count("YearSalary").alias("count"),
    f.mean("YearSalary").alias("mean"),
    f.stddev("YearSalary").alias("stddev"),
    f.min("YearSalary").alias("min"),
    f.max("YearSalary").alias("max")
)
stats_salaries.show()
# Out:
# +-----+-----------------+-----------------+-------+--------+
# |count|             mean|           stddev|    min|     max|
# +-----+-----------------+-----------------+-------+--------+
# |  562|75456.41459074733|37282.63900638703|26400.0|850000.0|
# +-----+-----------------+-----------------+-------+--------+

# %% [markdown]
# +-----+-----------------+-----------------+-------+--------+
# |count|             mean|           stddev|    min|     max|
# +-----+-----------------+-----------------+-------+--------+
# |  562|75456.41459074733|37282.63900638703|26400.0|850000.0|
# +-----+-----------------+-----------------+-------+--------+

# %% [markdown]
# La tabla a continuación muestra un análisis descriptivo de los salarios anuales (YearSalary) para profesionales en nivel senior en Alemania. Los datos proporcionan una visión general de la distribución salarial en este segmento:
#
# | Count |           Mean |         Stddev |    Min |     Max |
# |-------|-----------------|-----------------|--------|---------|
# |   562 | 75456.41459074733 | 37282.63900638703 | 26400.0 | 850000.0 |
#
# - **Count**: Representa el número total de registros de salarios en el nivel senior, que en este caso es 562.
#
# - **Mean**: El salario promedio anual es de 75,456.41 EUR.
#
# - **Stddev**: La desviación estándar es de 37,282.64 EUR, lo que indica una variabilidad considerable en los salarios.
#
# - **Min**: El salario más bajo registrado es de 26,400 EUR.
#
# - **Max**: El salario más alto registrado es de 850,000 EUR.

# %%
#Mostramos los datos en un histograma
from pyspark_dist_explore import hist
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
hist(ax, salaries2020_senior.select('YearSalary'), bins=16, color=['red'])
plt.title("Histograma de Salarios Anuales en Nivel Senior")
plt.xlabel("Salario Anual (EUR)")
plt.ylabel("Frecuencia")
plt.grid(axis='y', alpha=0.75)

# %%
#Ya que hay algunos outliers, procederemos a filtrar los datos usando como regla los cuartiles, para descartar todos los datos menores de Q1 y mayores a Q3
quartiles = salaries2020_senior.approxQuantile("YearSalary", [0.25, 0.75], 0.01)
q1 = quartiles[0]
q3 = quartiles[1]
iqr = q3 - q1
salaries2020_senior_clean = salaries2020_senior.filter((col("YearSalary") >= (q1 - 1.5 * iqr)) & (col("YearSalary") <= (q3 + 1.5 * iqr)))
salaries2020_senior_clean.count()
# Out:
# 523

# %%
#Mostramos los datos en un histograma
from pyspark_dist_explore import hist
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
hist(ax, salaries2020_senior_clean.select('YearSalary'), bins=16, color=['green'])
plt.title("Histograma de Salarios Anuales en Nivel Senior (Limpios)")
plt.xlabel("Salario Anual (EUR)")
plt.ylabel("Frecuencia")
plt.grid(axis='y', alpha=0.75)

# %%
#Procedemos a comparar los estadisticas entre hombres y mujeres
#Primero sacamos el analisis descriptivo entre generos
stats_gender = salaries2020_senior_clean.groupBy("Gender").agg(
    f.count("YearSalary").alias("count"),
    f.mean("YearSalary").alias("mean"),
    f.stddev("YearSalary").alias("stddev"),
    f.min("YearSalary").alias("min"),
    f.max("YearSalary").alias("max")
)
stats_gender.show()
# Out:
# +------+-----+-----------------+------------------+-------+--------+
# |Gender|count|             mean|            stddev|    min|     max|
# +------+-----+-----------------+------------------+-------+--------+
# |Female|   56|66751.78571428571|11089.929765683468|45000.0| 88000.0|
# |  Male|  467|72751.67665952891| 10847.37206522423|44000.0|102000.0|
# +------+-----+-----------------+------------------+-------+--------+

# %%
#Graficamos los datos
import pandas as pd
gender_data = stats_gender.select("Gender", "mean", "stddev").collect()


df = pd.DataFrame(gender_data, columns=["Gender", "mean", "stddev"])

# Plotting
plt.bar(df['Gender'], df['mean'], yerr=df['stddev'], capsize=5)
plt.xlabel("Género")
plt.ylabel("Salario Anual Promedio (EUR)")
plt.title("Comparación de Salarios Anuales Promedio entre Hombres y Mujeres")
plt.show()

# %%
#Graficamos en histogramas separados
male_salaries = salaries2020_senior_clean.filter(col("Gender") == "Male").select("YearSalary").toPandas()
female_salaries = salaries2020_senior_clean.filter(col("Gender") == "Female").select("YearSalary").toPandas()

plt.figure(figsize=(10, 6))

plt.hist(male_salaries["YearSalary"], bins=16, alpha=0.5, label="Hombres", color='blue', edgecolor='black')
plt.hist(female_salaries["YearSalary"], bins=16, alpha=0.5, label="Female", color='red', edgecolor='black')

plt.title("Histograma del Salario Anual por Genero")
plt.xlabel("Salario Anual (EUR)")
plt.ylabel("Frecuencia")

plt.legend()

plt.show()

# %% [markdown]
# #### 2.1.2.1 Conclusiones
# - **Brecha Salarial de Género:** Los resultados muestran una brecha salarial de género en el nivel senior en Alemania, con los hombres ganando en promedio más que las mujeres. Esta diferencia puede estar influenciada por varios factores como pueden ser el rol específico, la experiencia y las habilidades adicionales.
#
# - **Variabilidad Salarial:** La similitud en la desviación estándar entre los géneros sugiere que la dispersión de los salarios es comparable, pero la diferencia en los salarios máximos sugiere posibles desigualdades en el acceso a los puestos mejor remunerados.
# - **Poca cantidad de datos**: La cantidad de registros (56 para mujeres frente a 467 para hombres) puede sugerir que las carreras relacionadas con IT no atraen tanto a las mujeres, o que hay menos mujeres en niveles senior. Sin embargo, considerando que estos datos son del 2020 y que para alcanzar el nivel senior se requieren varios años de experiencia, es probable que en la actualidad haya más mujeres en este campo. Sería valioso realizar análisis adicionales comparando los datos de diferentes años para identificar posibles tendencias de aumento en la representación femenina en niveles senior.

# %%
###
